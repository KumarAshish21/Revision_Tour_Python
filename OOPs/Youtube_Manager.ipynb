# %%
import json

def load_data():
    try:
        with open('youtube.txt', 'r') as file:
            return json.load(file)
    except FileNotFoundError:
        return []

def save_data_helper(videos):
    with open('youtube.txt', 'w') as file:
        json.dump(videos, file)

def list_all_videos(videos):
    for index, video in enumerate(videos, start=1):
        print(f"{index}. {video['name']}, Duration: {video['time']} ")

def add_video(videos):
    name = input("Enter Video Name: ")
    time = input("Enter video time: ")
    videos.append({'name': name, 'time': time})
    save_data_helper(videos)

def update_video(videos):
    list_all_videos(videos)
    index=input("Enter the video number to update")
    if 1 <= index <= len(videos):
        name = input("Enter the new video name")
        time =input("Enter the new video time")
        videos[index-1] = {'name':name, 'time':time}
        save_data_helper(videos)
    else:
        print("Invaild index selected")
    

def delete_video(videos):
    list_all_videos(videos)
    index = int(input("Enter the video number to be deleted"))
    if 1 <= index <= len(videos):
        del videos[index-1]
        save_data_helper(videos)
    else:
        print("Invaild video index selected")
    

def main():
    videos = load_data()  # Corrected assignment
    while True:
        print("\n Youtube Manager")
        print("1. List all youtube videos")
        print("2. Add a new video")
        print("3. Update a video")
        print("4. Delete a video")
        print("5. Exit the app")
        choice = input("Enter your choice: ")

        match choice:
            case "1":
                list_all_videos(videos)
            case "2":
                add_video(videos)
            case "3":
                update_video(videos)
            case "4":
                delete_video(videos)
            case "5":
                break
            case _:
                print("Invalid choice")

if __name__ == "__main__":
    main()
# Out:
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 4
# 1. Python aur Backend, Duration: 15 Hours
# 2. Python aur Django, Duration: 25 Hours
# Enter the video number to be deleted2
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 1
# 1. Python aur Backend, Duration: 15 Hours
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter Video Name: Chai aur Django
# Enter video time: 25
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 1
# 1. Python aur Backend, Duration: 15 Hours
# 2. Chai aur Django, Duration: 25
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter Video Name: JavaScript
# Enter video time: 15
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter Video Name: React
# Enter video time: 8
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter Video Name: Node JS
# Enter video time: 25
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 1
# 1. Python aur Backend, Duration: 15 Hours
# 2. Chai aur Django, Duration: 25
# 3. JavaScript, Duration: 15
# 4. React, Duration: 8
# 5. Node JS, Duration: 25
#
#  Youtube Manager
# 1. List all youtube videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 5

# %%
import sqlite3

conn = sqlite3.connect('youtube_videos.db')
cursor = conn.cursor()
cursor.execute('''
    CREATE TABLE IF NOT EXISTS videos (
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL,
        time TEXT NOT NULL
    )
''')

def list_videos():
    cursor.execute("SELECT * FROM videos")
    for row in cursor.fetchall():
        print(row)

def add_video(name, time):
    cursor.execute("INSERT INTO videos (name, time) VALUES (?, ?)", (name, time))
    conn.commit()

def update_video(video_id, new_name, new_time):
    cursor.execute("UPDATE videos SET name = ?, time = ? WHERE id = ?", (new_name, new_time, video_id))
    conn.commit()

def delete_video(video_id):
    cursor.execute("DELETE FROM videos WHERE id = ?", (video_id,))
    conn.commit()

def main():
    while True:
        print("\nYoutube manager app with DB")
        print("1. List Videos")
        print("2. Add Videos")
        print("3. Update Videos")
        print("4. Delete Videos")
        print("5. Exit app")
        choice = input("Enter your choice: ")
        
        if choice == '1':
            list_videos()
        elif choice == '2':
            name = input("Enter the video name: ")
            time = input("Enter the video time: ")
            add_video(name, time)
        elif choice == '3':
            video_id = input("Enter video ID to update: ")
            name = input("Enter the new video name: ")
            time = input("Enter the new video time: ")
            update_video(video_id, name, time)
        elif choice == '4':
            video_id = input("Enter video ID to delete: ")
            delete_video(video_id)
        elif choice == '5':
            break
        else:
            print("Invalid Choice")

    conn.close()

if __name__ == "__main__":
    main()
# Out:
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 2
# Enter the video name: Python aur Backend
# Enter the video time: 15 hours
#
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 1
# (1, 'Python aur Backend', '15 hours')
#
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 1
# (1, 'Python aur Backend', '15 hours')
#
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 2
# Enter the video name: Python aur Database
# Enter the video time: 40 mints
#
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 3
# Enter video ID to update: 1
# Enter the new video name: Python aur Django
# Enter the new video time: 15 Hours
#
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 1
# (1, 'Python aur Django', '15 Hours')
# (2, 'Python aur Database', '40 mints')
#
# Youtube manager app with DB
# 1. List Videos
# 2. Add Videos
# 3. Update Videos
# 4. Delete Videos
# 5. Exit app
# Enter your choice: 5

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in /Users/youngmanindia/anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/youngmanindia/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/youngmanindia/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/youngmanindia/anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/youngmanindia/anaconda3/lib/python3.11/site-packages (from requests) (2023.7.22)
